# %% [markdown]
# # Analyser des données non structurées : du texte

# %%
import pandas as pd

# %% [markdown]
# ## Charger les données

# %%
url = "https://zenodo.org/record/5827206/files/SOSP_Export_base%20de%20donn%C3%A9es%20diffusable.csv"
data = pd.read_csv(url)

# %% [markdown]
# ## Utiliser des outils déjà disponibles
#
# Evidement ces étapes sont souvent faites et il est possible d'accélérer

# %%
# à ré-exécuter si besoin (long)
# %pip install -U spacy

# %%
# à ré-exécuter si besoin (long)
# !python -m spacy download fr_dep_news_trf

# %% [markdown]
# Par exemple sur les stopwords

# %%
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop

# %%
#fr_stop

# %% [markdown]
# Mais aussi pour créer des sacs de mots

# %% [markdown]
# Il y a des outils de haut niveau paramétrables pour directement obtenir les formats souhaités. Mais cela demande potentiellement de rentrer un peu dans la bibliothèque.
#
# scikit-learn a un format générique :
# * on crée un objet,
# * on le `fit` sur un ensemble ou sous-ensemble de données (eg. d'entraînement),
# * on l'utilise pour transformer les données (`transform`) ou pour faire une prédiction (`predict`)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(stop_words=list(fr_stop), min_df=5)

# %%
X = vectorizer.fit_transform(data["outils"])
# Out:
# /home/mathieu/miniconda3/envs/pyshs/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['neuf', 'qu', 'quelqu'] not in stop_words.
#   warnings.warn(

# %%
X.toarray().shape
# Out:
# (1089, 260)

# %%
#vectorizer.get_feature_names_out()

# %% [markdown]
# D'autres traitements sont directement disponibles, par exemple le calcul de tf-idf.

# %% [markdown]
# # Utiliser les modèles de langage

# %% [markdown]
# ## Quelques mots sur le principe des transformers

# %% [markdown]
# ## Présentation de la bibliothèque SpaCy

# %% [markdown]
# ## Application sur le champ libre
#
# - récupérer les noms ?

# %%
questions = pd.read_csv("https://zenodo.org/record/5827206/files/SOSP_metadonnees_variables.csv", header=31)
questions
# Out:
#                           Nom variable
# 0                                   ID  \
# 1                    contexte_travail
# 2                   fonction_recherche
# 3                 statut_professionnel
# 4           statut_professionnel_autre
# ..                                 ...
# 126  compatibilite_diffusion_partage\n
# 127    evolutions_pratiques_numeriques
# 128                               sexe
# 129                   Disciplines_9niv
# 130         annee_naissance_recod10niv
#
#                                               Question
# 0                                                  NaN  \
# 1    Habituellement, pour une opération de recherch...
# 2        Quelle est votre fonction dans la recherche ?
# 3                Quel est votre statut professionnel ?
# 4                     Si, autre pouvez-vous préciser ?
# ..                                                 ...
# 126  34 - Le partage et la diffusion des données vo...
# 127  35 - Selon vous, vos pratiques numériques vont...
# 128                             Quel est votre genre ?
# 129  Quelle est votre discipline principale de rech...
# 130              Quelle est votre année de naissance ?
#
#                         Modalités de réponse proposées Colonne
# 0                                                  NaN       A  \
# 1    je travaille seul   nous sommes entre 2 et 5 p...       B
# 2    doctorant / doctorante (y compris CIFRE)   maî...       C
# 3    Fonctionnaire ou assimilé en CDD   en CDI   po...       D
# 4                                     Question ouverte       E
# ..                                                 ...     ...
# 126                                   Question ouverte      DW
# 127                                   Question ouverte      DX
# 128     Une femme Un homme Je ne souhaite pas répondre      DY
# 129  Sciences de l'ingénieur  Sciences humaines\nSc...      DZ
# 130  Moins de 25 ans  25 à 30 ans 31 à 35 ans\n36 à...      EA
#
#               Observations _Commentaires
# 0               Identifiant de l’observé
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 126  mots anonymisés sous forme de XXXXX
# 127  mots anonymisés sous forme de XXXXX
# 128                                  NaN
# 129            recodage en 9 disciplines
# 130                                  NaN
#
# [131 rows x 5 columns]

# %%
questions[questions["Modalités de réponse proposées"] == "Question ouverte"]
# Out:
#                           Nom variable
# 4           statut_professionnel_autre  \
# 43                  volumetrie_donnees
# 46                     Tiers_archivage
# 47               Tiers_archivage_recod
# 57         logiciel_production_donnees
# 60                    outils_nettoyage
# 62                     Outils_analyses
# 64                Outils_visualisation
# 75            outils_production_figure
# 126  compatibilite_diffusion_partage\n
# 127    evolutions_pratiques_numeriques
#
#                                               Question
# 4                     Si, autre pouvez-vous préciser ?  \
# 43   Quelle est la quantité estimée de ces données ...
# 46            Si oui, à quels tiers les confiez-vous ?
# 47            Si oui, à quels tiers les confiez-vous ?
# 57   Quels logiciels utilisez-vous pour produire de...
# 60                     Pouvez-vous précisez lesquels ?
# 62                     Pouvez-vous précisez lesquels ?
# 64                     Pouvez-vous précisez lesquels ?
# 75   Quels outils utilisez-vous pour générer des fi...
# 126  34 - Le partage et la diffusion des données vo...
# 127  35 - Selon vous, vos pratiques numériques vont...
#
#     Modalités de réponse proposées Colonne
# 4                 Question ouverte       E  \
# 43                Question ouverte      AR
# 46                Question ouverte      AU
# 47                Question ouverte      AV
# 57                Question ouverte      BF
# 60                Question ouverte      BI
# 62                Question ouverte      BK
# 64                Question ouverte      BM
# 75                Question ouverte      BX
# 126               Question ouverte      DW
# 127               Question ouverte      DX
#
#                           Observations _Commentaires
# 4                                                NaN
# 43                                               NaN
# 46                                               NaN
# 47   Recodage des réponses de la variable précédente
# 57                                               NaN
# 60                                               NaN
# 62                                               NaN
# 64                                               NaN
# 75                                               NaN
# 126              mots anonymisés sous forme de XXXXX
# 127              mots anonymisés sous forme de XXXXX

# %%
questions_ouvertes = (
    questions[questions["Modalités de réponse proposées"] == "Question ouverte"]["Nom variable"]
    .str.lower()
    .str.strip()
    .tolist()
)
questions_ouvertes
# Out:
# ['statut_professionnel_autre',
#  'volumetrie_donnees',
#  'tiers_archivage',
#  'tiers_archivage_recod',
#  'logiciel_production_donnees',
#  'outils_nettoyage',
#  'outils_analyses',
#  'outils_visualisation',
#  'outils_production_figure',
#  'compatibilite_diffusion_partage',
#  'evolutions_pratiques_numeriques']

# %%
data = data.rename(columns={x: x.lower().strip() for x in data.columns.tolist()})
data
# Out:
#         id                     contexte_travail
# 0        1  nous sommes entre 6 et 10 personnes  \
# 1        2     nous sommes plus de 50 personnes
# 2        3   nous sommes entre 2 et 5 personnes
# 3        4   nous sommes entre 2 et 5 personnes
# 4        5   nous sommes entre 2 et 5 personnes
# ...    ...                                  ...
# 1084  1085   nous sommes entre 2 et 5 personnes
# 1085  1086   nous sommes entre 2 et 5 personnes
# 1086  1087   nous sommes entre 2 et 5 personnes
# 1087  1088   nous sommes entre 2 et 5 personnes
# 1088  1089   nous sommes entre 2 et 5 personnes
#
#                                      fonction_recherche
# 0     professeur / professeure des universités et as...  \
# 1                   ingénieur / ingénieure de recherche
# 2        maître / maîtresse de conférences et assimilés
# 3     directeur / directrice de recherche (CNRS, INS...
# 4              doctorant / doctorante (y compris CIFRE)
# ...                                                 ...
# 1084  chargé / chargée de recherche (CNRS, INSERM, I...
# 1085  chargé / chargée de recherche (CNRS, INSERM, I...
# 1086     maître / maîtresse de conférences et assimilés
# 1087  directeur / directrice de recherche (CNRS, INS...
# 1088     maître / maîtresse de conférences et assimilés
#
#            statut_professionnel statut_professionnel_autre
# 0     fonctionnaire ou assimilé                        NaN  \
# 1                        en CDI                        NaN
# 2     fonctionnaire ou assimilé                        NaN
# 3     fonctionnaire ou assimilé                        NaN
# 4                        en CDD                        NaN
# ...                         ...                        ...
# 1084                     en CDI                        NaN
# 1085  fonctionnaire ou assimilé                        NaN
# 1086  fonctionnaire ou assimilé                        NaN
# 1087  fonctionnaire ou assimilé                        NaN
# 1088  fonctionnaire ou assimilé                        NaN
#
#       annee_premiere_publi            systeme_exploitation
# 0                     1995                         Windows  \
# 1                     2005                         Windows
# 2                     2006                         Windows
# 3                     1989  Windows;autres OS (Android...)
# 4                     2015                           MacOS
# ...                    ...                             ...
# 1084                  2004                         Windows
# 1085                  1987                           Linux
# 1086                  1992                         Windows
# 1087                  1982                           Linux
# 1088                  2011                   Windows;Linux
#
#      usage_telephone_mobile
# 0                  rarement  \
# 1                  rarement
# 2                   parfois
# 3                   souvent
# 4                   souvent
# ...                     ...
# 1084                parfois
# 1085                 jamais
# 1086                 jamais
# 1087                 jamais
# 1088               rarement
#
#      outils_gestion_travail_av_confinement_visioconférence
# 0                                               parfois     \
# 1                                               parfois
# 2                                              rarement
# 3                                              rarement
# 4                                              rarement
# ...                                                 ...
# 1084                                             jamais
# 1085                                           rarement
# 1086                                            souvent
# 1087                                           rarement
# 1088                                            parfois
#
#      outils_gestion_travail_av_confinement_planification_rdv  ...
# 0                                               souvent       ...  \
# 1                                               parfois       ...
# 2                                               souvent       ...
# 3                                               souvent       ...
# 4                                               parfois       ...
# ...                                                 ...       ...
# 1084                                            parfois       ...
# 1085                                           rarement       ...
# 1086                                            souvent       ...
# 1087                                            souvent       ...
# 1088                                            souvent       ...
#
#      souhait_partage_donnees_produites_sans_restriction
# 0                                                   oui  \
# 1                                                   oui
# 2                                                   oui
# 3                                                   non
# 4                                                   oui
# ...                                                 ...
# 1084                                                oui
# 1085                                                oui
# 1086                                                oui
# 1087                                                non
# 1088                                                oui
#
#                         compatibilite_diffusion_partage
# 0                                                   oui  \
# 1                                                   NaN
# 2                     oui, tout est dans la chronologie
# 3                                                   Oui
# 4                                                   Oui
# ...                                                 ...
# 1084  Oui, si les innovations ont été protégées en a...
# 1085  je ne pratique pas des 'activités de valorisat...
# 1086                                                oui
# 1087  Je ne sais pas vraiment repondre a ces questio...
# 1088                                                Oui
#
#                         evolutions_pratiques_numeriques
# 0                                        je ne sais pas  \
# 1                                                   NaN
# 2                                                   non
# 3                                           Aucune idée
# 4                                                   Oui
# ...                                                 ...
# 1084  Mise en place d'un plan de partage des données...
# 1085                        je vais prendre ma retraite
# 1086                                                NaN
# 1087                                     Je ne sais pas
# 1088  Oui, vers plus d'ouverture mais je ne sais pas...
#
#                              sexe   disciplines_9niv
# 0                        un homme  Sciences humaines  \
# 1                        un homme           Médecine
# 2                        un homme           Médecine
# 3                       une femme           Médecine
# 4                       une femme           Médecine
# ...                           ...                ...
# 1084                     un homme                NaN
# 1085                     un homme                NaN
# 1086                     un homme                NaN
# 1087                    une femme                NaN
# 1088  je ne souhaite pas répondre                NaN
#
#      annee_de_naissance-recod10niv
# 0                      61 à 65 ans  \
# 1                      46 à 50 ans
# 2                      36 à 40 ans
# 3                      56 à 60 ans
# 4                      31 à 35 ans
# ...                            ...
# 1084                   41 à 45 ans
# 1085                   61 à 65 ans
# 1086                   56 à 60 ans
# 1087                   61 à 65 ans
# 1088                   36 à 40 ans
#
#                                                  outils
# 0     lime survey tableur pour les données statistiques  \
# 1                   excell word clean outil statistique
# 2                                                  jasp
# 3     question peu claire.  excel, spss, logiciels d...
# 4                          ? excel r image j dti studii
# ...                                                 ...
# 1084             epiinfo\nxlstat epiinfo\nxlstat\nexcel
# 1085                                       xpdf, evince
# 1086                                 openrefine, talend
# 1087
# 1088             r, excel r, mplus, stata, sas, excel r
#
#                                              outils_alt
# 0     lime survey tableur pour les données statistiques  \
# 1                   excell word clean outil statistique
# 2                                                  jasp
# 3     question peu claire.  excel, spss, logiciels d...
# 4                          ? excel r image j dti studii
# ...                                                 ...
# 1084             epiinfo\nxlstat epiinfo\nxlstat\nexcel
# 1085                                       xpdf, evince
# 1086                                 openrefine, talend
# 1087
# 1088             r, excel r, mplus, stata, sas, excel r
#
#                                            outils_token labels
# 0                 [lime, survey, tableur, statistiques]      2
# 1             [excell, word, clean, outil, statistique]      0
# 2                                                [jasp]      3
# 3     [question, peu, claire, excel, spss, imagerie,...      1
# 4                     [excel, r, image, j, dti, studii]      1
# ...                                                 ...    ...
# 1084          [epiinfo, xlstat, epiinfo, xlstat, excel]      1
# 1085                                     [xpdf, evince]      1
# 1086                               [openrefine, talend]      0
# 1087                                                 []      2
# 1088         [r, excel, r, mplus, stata, sas, excel, r]      1
#
# [1089 rows x 135 columns]

# %%
data[questions_ouvertes].apply(lambda x: x.str.len().describe(), axis=0).transpose()
# Out:
#                                   count        mean         std   min    25%
# statut_professionnel_autre          7.0   49.000000   41.717303  21.0  24.00  \
# volumetrie_donnees               1081.0   21.663275   33.037989   1.0   4.00
# tiers_archivage                   505.0   23.154455   24.143747   1.0   9.00
# tiers_archivage_recod             491.0   18.517312   11.105487   3.0  11.00
# logiciel_production_donnees      1082.0   39.624769   52.660816   1.0  12.00
# outils_nettoyage                  333.0   22.408408   29.819460   1.0   6.00
# outils_analyses                   646.0   26.287926   37.446446   1.0   7.00
# outils_visualisation              743.0   23.269179   29.747549   1.0   7.00
# outils_production_figure          852.0   22.438967   26.127542   1.0   8.75
# compatibilite_diffusion_partage   968.0   55.552686  123.046083   1.0   3.00
# evolutions_pratiques_numeriques   882.0  101.564626  138.877954   1.0  14.00
#
#                                   50%     75%     max
# statut_professionnel_autre       32.0   51.50   139.0
# volumetrie_donnees               11.0   25.00   379.0
# tiers_archivage                  18.0   28.00   255.0
# tiers_archivage_recod            13.0   24.00    61.0
# logiciel_production_donnees      25.0   46.00   619.0
# outils_nettoyage                 13.0   26.00   263.0
# outils_analyses                  15.0   31.75   413.0
# outils_visualisation             15.0   27.50   316.0
# outils_production_figure         17.0   28.00   375.0
# compatibilite_diffusion_partage   4.0   59.25  1459.0
# evolutions_pratiques_numeriques  59.0  126.75  1240.0

# %%
epn = data["evolutions_pratiques_numeriques"].dropna()
epn
# Out:
# 0                                          je ne sais pas
# 2                                                     non
# 3                                             Aucune idée
# 4                                                     Oui
# 6       Je ne sais pas. Fonction de l'accès à des form...
#                               ...
# 1083    Les pratiques vont se renforcer et se professi...
# 1084    Mise en place d'un plan de partage des données...
# 1085                          je vais prendre ma retraite
# 1087                                       Je ne sais pas
# 1088    Oui, vers plus d'ouverture mais je ne sais pas...
# Name: evolutions_pratiques_numeriques, Length: 882, dtype: object

# %%
import spacy

# %%
nlp = spacy.load("fr_dep_news_trf")

# %%
un_texte = "La petite ferme la porte. La belle brise la glace. Le chat porte un chapeau."
doc = nlp(un_texte)
doc
# Out:
# La petite ferme la porte. La belle brise la glace. Le chat porte un chapeau.

# %%
for token in doc:
    print("\t".join(str(x) for x in [token.text, token.lemma_, token.pos_, token.morph, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop]))
# Out:
# La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	DET	det	Xx	True	True
# petite	petit	ADJ	Gender=Fem|Number=Sing	ADJ	amod	xxxx	True	False
# ferme	ferme	NOUN	Gender=Fem|Number=Sing	NOUN	nsubj	xxxx	True	False
# la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	DET	det	xx	True	True
# porte	porte	NOUN	Gender=Fem|Number=Sing	NOUN	ROOT	xxxx	True	False
# .	.	PUNCT		PUNCT	punct	.	False	False
# La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	DET	det	Xx	True	True
# belle	bel	ADJ	Gender=Fem|Number=Sing	ADJ	amod	xxxx	True	False
# brise	brise	NOUN	Gender=Fem|Number=Sing	NOUN	ROOT	xxxx	True	False
# la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	DET	det	xx	True	True
# glace	glace	NOUN	Gender=Fem|Number=Sing	NOUN	nmod	xxxx	True	False
# .	.	PUNCT		PUNCT	punct	.	False	False
# Le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	DET	det	Xx	True	True
# chat	chat	NOUN	Gender=Masc|Number=Sing	NOUN	nsubj	xxxx	True	False
# porte	porte	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	VERB	ROOT	xxxx	True	False
# un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	DET	det	xx	True	True
# chapeau	chapeau	NOUN	Gender=Masc|Number=Sing	NOUN	obj	xxxx	True	False
# .	.	PUNCT		PUNCT	punct	.	False	False

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="81e094d042184703921c8818bcc47306-0" class="displacy" width="2675" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">petite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">ferme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">porte.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">belle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">brise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">glace.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">chat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">porte</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">chapeau.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-2" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-4" stroke-width="2px" d="M945,177.0 C945,2.0 1275.0,2.0 1275.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-5" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,179.0 L1112,167.0 1128,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-81e094d042184703921c8818bcc47306-0-6" stroke-width="2px" d="M1470,177.0 C1470,89.5 1620.0,89.5 1620.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-81e094d042184703921c8818bcc47306-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-ar

# %%
displacy.render(list(doc.sents), style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="281827b3386743e98649570bdf500a46-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">petite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">ferme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">porte.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-0-2" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="281827b3386743e98649570bdf500a46-1" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">belle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">brise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">glace.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-1-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-1-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-1-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-281827b3386743e98649570bdf500a46-1-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-281827b3386743e98649570bdf500a46-1-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg>
#
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="281827b3386743e98649570bdf500a46-2" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: A

# %%
displacy.render(doc, style="ent")
# Out:
# /home/mathieu/miniconda3/envs/pyshs/lib/python3.11/site-packages/spacy/displacy/__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">La petite ferme la porte. La belle brise la glace. Le chat porte un chapeau.</div></span>

# %%
un_autre_texte = "Jeanne part pour Genève. Elle poursuivra ensuite son voyage vers Big Apple."
doc2 = nlp(un_autre_texte)

# %%
displacy.render(doc2, style="ent")
# Out:
# /home/mathieu/miniconda3/envs/pyshs/lib/python3.11/site-packages/spacy/displacy/__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Jeanne part pour Genève. Elle poursuivra ensuite son voyage vers Big Apple.</div></span>

# %%
#!python -m spacy download fr_core_news_md

# %%
nlp_md = spacy.load("fr_core_news_md")

# %%
doc2_md = nlp_md(un_autre_texte)
doc2_md
# Out:
# Jeanne part pour Genève. Elle poursuivra ensuite son voyage vers Big Apple.

# %%
displacy.render(doc2_md, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeanne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  part pour
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Genève
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Elle poursuivra ensuite son voyage vers
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Big Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
epns = epn.tolist()
epns

# %%
docs_md = [nlp_md(x) for x in epns]
docs_md

# %%
displacy.render(docs_md, style="ent")

# %% [markdown]
# # Petite application de haut niveau : sentiment analysis
#
# ATTENTION CA MARCHE PAS SUR MON MAC : MATTHIEU ?
#
#
# Identifier les personnes qui ont un ressenti négatif par rapport aux évolutions du numériques
#
# https://huggingface.co/cmarkea/distilcamembert-base-sentiment

# %%
from transformers import pipeline

analyzer = pipeline(
    task='text-classification',
    model="cmarkea/distilcamembert-base-sentiment",
    tokenizer="cmarkea/distilcamembert-base-sentiment"
)

# %%
epsn_sent = analyzer(epns)
epsn_sent

# %%
for reponse, sent in zip(epn, epsn_sent):
    print(reponse, sent["label"], sent["score"])

# %%
for reponse, sent in zip(epn, epsn_sent):
    if sent["label"] in ["1 star", "2 stars"]:
        print(reponse, sent["label"], sent["score"])

# %%
df_sent = pd.DataFrame(
    data={
        "reponse": epn,
        "sentiment": [x["label"] for x in epsn_sent],
        "sent_score": [x["score"] for x in epsn_sent],
    }
)
df_sent
# Out:
#                                                 reponse sentiment  sent_score
# 0                                        je ne sais pas   3 stars    0.311197
# 2                                                   non    1 star    0.285603
# 3                                           Aucune idée    1 star    0.592063
# 4                                                   Oui   4 stars    0.374047
# 6     Je ne sais pas. Fonction de l'accès à des form...   3 stars    0.314710
# ...                                                 ...       ...         ...
# 1083  Les pratiques vont se renforcer et se professi...   4 stars    0.468114
# 1084  Mise en place d'un plan de partage des données...   4 stars    0.474919
# 1085                        je vais prendre ma retraite   5 stars    0.342706
# 1087                                     Je ne sais pas   3 stars    0.307354
# 1088  Oui, vers plus d'ouverture mais je ne sais pas...   3 stars    0.358201
#
# [882 rows x 3 columns]

# %%
df_sent[(df_sent["sentiment"] == "1 star") | (df_sent["sentiment"] == "2 stars")]
# Out:
#                                                 reponse sentiment  sent_score
# 2                                                   non    1 star    0.285603
# 3                                           Aucune idée    1 star    0.592063
# 24                                          Aucune idée    1 star    0.592063
# 25                                                  Non    1 star    0.237107
# 26                               NON,je suis trop vieux    1 star    0.725573
# ...                                                 ...       ...         ...
# 1058  Il est possible que je sois obligé d'utiliser ...   2 stars    0.433645
# 1061                                                non    1 star    0.285603
# 1070  Difficile à dire. En l'absence de mise à dispo...   2 stars    0.515802
# 1071  non elles évolueront peu. L'objectif étant dés...   2 stars    0.305642
# 1082                       Non pas de manière radicale.   2 stars    0.255308
#
# [150 rows x 3 columns]

# %%
df_sent[(df_sent["sentiment"] == "1 star")].sort_values(by="sent_score", ascending=False)
# Out:
#                                                 reponse sentiment  sent_score
# 1055  augmenter nos emmerdes. On est bouffé par 150,...    1 star    0.930310
# 26                               NON,je suis trop vieux    1 star    0.725573
# 159   Non car aucune formation et aucun temps pour l...    1 star    0.687645
# 566                                      aucune idée...    1 star    0.661838
# 58                                         Aucune idée.    1 star    0.658081
# ...                                                 ...       ...         ...
# 709                                                 Non    1 star    0.237107
# 891                                                 Non    1 star    0.237107
# 543                                                 Non    1 star    0.237107
# 967                                        Incrémentale    1 star    0.226097
# 1030                                               FAIR    1 star    0.218053
#
# [89 rows x 3 columns]

# %%
df_sent[(df_sent["sentiment"] == "1 star")].sort_values(by="sent_score", ascending=False).iloc[0]["reponse"]
# Out:
# "augmenter nos emmerdes. On est bouffé par 150,000 trucs à la con, et on nous en rajoute ... \nLes équipes sont à bout, les crédits n'existent plus, on a 0 reconnaissance.\nfaut-il répondre à toutes ces demandes diverses et avariées, réponse: comme pour le COVID: négatif."
